# %% [markdown]
# <a href="https://colab.research.google.com/github/parva4/python_timeseries/blob/main/Timeseries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
dates=pd.date_range(start='2021-01-01',end='2021-01-10',freq='d').to_list()
num=[10,8,4,15,25,2,6,17,8,12]
x=pd.DataFrame({'dates':dates,'numbers':num})
#x.plot.line(x='dates',y='numbers')
x['Moving average']=x.rolling(window=4).mean()
x.plot.line(x='dates',y=['numbers','Moving average']) #plotting MA

# %%
#center=True
import pandas as pd
dates=pd.date_range(start='2021-01-01',end='2021-01-10',freq='d').to_list()
num=[10,8,4,15,25,2,6,17,8,12]
x=pd.DataFrame({'dates':dates,'numbers':num})
#x.plot.line(x='dates',y='numbers')
x['Rolling average']=x.rolling(window=4,center=True).mean()
#x.plot.line(x='dates',y=['numbers','Moving average']) #plotting MA
x
# Out:
#        dates  numbers  Moving average
# 0 2021-01-01       10             NaN
# 1 2021-01-02        8             NaN
# 2 2021-01-03        4            9.25
# 3 2021-01-04       15           13.00
# 4 2021-01-05       25           11.50
# 5 2021-01-06        2           12.00
# 6 2021-01-07        6           12.50
# 7 2021-01-08       17            8.25
# 8 2021-01-09        8           10.75
# 9 2021-01-10       12             NaN

# %%
#min periods
import pandas as pd
import numpy as np
dates=pd.date_range(start='2021-01-01',end='2021-01-10',freq='d').to_list()
num=[10,8,4,15,25,2,6,17,8,12]
x=pd.DataFrame({'dates':dates,'numbers':num})
#x.plot.line(x='dates',y='numbers')
x.iloc[5:7,1]=np.NaN
x['Rolling average']=x.rolling(4,min_periods=3).mean()
#x.plot.line(x='dates',y=['numbers','Moving average']) #plotting MA
x
# Out:
#        dates  numbers  Rolling average
# 0 2021-01-01     10.0              NaN
# 1 2021-01-02      8.0              NaN
# 2 2021-01-03      4.0         7.333333
# 3 2021-01-04     15.0         9.250000
# 4 2021-01-05     25.0        13.000000
# 5 2021-01-06      NaN        14.666667
# 6 2021-01-07      NaN              NaN
# 7 2021-01-08     17.0              NaN
# 8 2021-01-09      8.0              NaN
# 9 2021-01-10     12.0        12.333333
